# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.9/276.9 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 89.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 133.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
# ...

# %%
from google.colab import userdata
ROBOFLOW_API = userdata.get('ROBOFLOW_API')

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=ROBOFLOW_API)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 1338/1338 [00:00<00:00, 2831.71it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
# !mv /content/football-players-detection-1 /content/drive/MyDrive/

# %%
import shutil

dst = "/content/drive/MyDrive/mini_project_playground"
shutil.move('/content/football-players-detection-1/train',
            f'{dst}/football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('/content/football-players-detection-1/test',
            f'{dst}/football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('/content/football-players-detection-1/valid',
            f'{dst}/football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# '/content/drive/MyDrive/mini_project_playground/football-players-detection-1/football-players-detection-1/valid'

# %%
shutil.move('/content/football-players-detection-1/data.yaml',
            f'{dst}/football-players-detection-1/football-players-detection-1/data.yaml'
            )
shutil.move('/content/football-players-detection-1/README.dataset.txt',
            f'{dst}/football-players-detection-1/football-players-detection-1/README.dataset.txt'
            )
shutil.move('/content/football-players-detection-1/README.roboflow.txt',
            f'{dst}/football-players-detection-1/football-players-detection-1/README.roboflow.txt'
            )
# Out:
# '/content/drive/MyDrive/mini_project_playground/football-players-detection-1/football-players-detection-1/README.roboflow.txt'

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
# !yolo task=detect mode=train \
model=yolov8m.pt \
data=/content/drive/MyDrive/mini_project_playground/football-players-detection-1/football-players-detection-1/data.yaml \
epochs=100 \
imgsz=640
# Out:
# ...
# Ultralytics 8.4.94 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/mini_project_playground/yolov8/
# !cp /content/runs/detect/train/weights/last.pt /content/drive/MyDrive/mini_project_playground/yolov8/

# %% [markdown]
# # Testing

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/mini_project_playground/yolov8/best.pt')
result = model.predict('/content/drive/MyDrive/mini_project_playground/test_inputs/test1.mp4', save=True)
print(result[0])

print("="*30)
for box in result[0].boxes:
  print(box)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/drive/MyDrive/mini_project_playground/test_inputs/test1.mp4: 384x640 1 ball, 1 goalkeeper, 24 players, 3 referees, 66.6ms
# video 1/1 (frame 2/750) /content/drive/MyDrive/mini_project_playground/test_inputs/test1.mp4: 384x640 1 ball, 1 goalkeeper, 24 players, 3 referees, 25.1ms
# ...
